# %%
import ROOT as rt
# Out:
# Welcome to JupyROOT 6.18/04

# %%
i = rt.TFile("AnalysisResults.root")
o = i.Get('h-lambda')

canvas = rt.TCanvas("canvas")

# %%
o.FindObject("fLambdaDaughterDCA").ProjectionX().Draw()
canvas.Draw()
