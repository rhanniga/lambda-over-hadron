# %%
import ROOT as rt
rt.gStyle.SetOptStat(0)
# Out:
# Welcome to JupyROOT 6.24/06

# %%
c = rt.TCanvas("c","c",800,600)
c.SetLeftMargin(0.15)

# %%
st_infile = rt.TFile("output/v0_highest_pt_avg6_sideband_subtraction_rsb_1135_115_sig_11_113_trig_40_80_assoc_20_40_delta_eta_12_normal_normal.root")
infile = rt.TFile("output/v0_avg6_sideband_subtraction_rsb_1135_115_sig_11_113_trig_40_80_assoc_20_40_delta_eta_12_normal_normal.root")

st_h_h_dphi_0_20 = st_infile.Get("h_h_dphi_0_20")
st_h_h_dphi_20_50 = st_infile.Get("h_h_dphi_20_50")
st_h_h_dphi_50_80 = st_infile.Get("h_h_dphi_50_80")

h_h_dphi_0_20 = infile.Get("h_h_dphi_0_20")
h_h_dphi_20_50 = infile.Get("h_h_dphi_20_50")
h_h_dphi_50_80 = infile.Get("h_h_dphi_50_80")

st_h_lambda_dphi_subtracted_0_20 = st_infile.Get("h_lambda_dphi_subtracted_0_20")
st_h_lambda_dphi_subtracted_20_50 = st_infile.Get("h_lambda_dphi_subtracted_20_50")
st_h_lambda_dphi_subtracted_50_80 = st_infile.Get("h_lambda_dphi_subtracted_50_80")

h_lambda_dphi_subtracted_0_20 = infile.Get("h_lambda_dphi_subtracted_0_20")
h_lambda_dphi_subtracted_20_50 = infile.Get("h_lambda_dphi_subtracted_20_50")
h_lambda_dphi_subtracted_50_80 = infile.Get("h_lambda_dphi_subtracted_50_80")

# %%
st_h_h_dphi_0_20.SetTitle("")
st_h_h_dphi_20_50.SetTitle("")
st_h_h_dphi_50_80.SetTitle("")

h_h_dphi_0_20.SetTitle("")
h_h_dphi_20_50.SetTitle("")
h_h_dphi_50_80.SetTitle("")

st_h_lambda_dphi_subtracted_0_20.SetTitle("")
st_h_lambda_dphi_subtracted_20_50.SetTitle("")
st_h_lambda_dphi_subtracted_50_80.SetTitle("")

h_lambda_dphi_subtracted_0_20.SetTitle("")
h_lambda_dphi_subtracted_20_50.SetTitle("")
h_lambda_dphi_subtracted_50_80.SetTitle("")

# %%
st_h_lambda_dphi_subtracted_0_20.GetXaxis().SetTitle("#Delta#varphi_{h-#Lambda}")
st_h_lambda_dphi_subtracted_0_20.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")
st_h_lambda_dphi_subtracted_20_50.GetXaxis().SetTitle("#Delta#varphi_{h-#Lambda}")
st_h_lambda_dphi_subtracted_20_50.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")
st_h_lambda_dphi_subtracted_50_80.GetXaxis().SetTitle("#Delta#varphi_{h-#Lambda}")
st_h_lambda_dphi_subtracted_50_80.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")

h_lambda_dphi_subtracted_0_20.GetXaxis().SetTitle("#Delta#varphi_{h-#Lambda}")
h_lambda_dphi_subtracted_0_20.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")
h_lambda_dphi_subtracted_20_50.GetXaxis().SetTitle("#Delta#varphi_{h-#Lambda}")
h_lambda_dphi_subtracted_20_50.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")
h_lambda_dphi_subtracted_50_80.GetXaxis().SetTitle("#Delta#varphi_{h-#Lambda}")
h_lambda_dphi_subtracted_50_80.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")

st_h_h_dphi_0_20.GetXaxis().SetTitle("#Delta#varphi_{h-h}")
st_h_h_dphi_0_20.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")
st_h_h_dphi_20_50.GetXaxis().SetTitle("#Delta#varphi_{h-h}")
st_h_h_dphi_20_50.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")
st_h_h_dphi_50_80.GetXaxis().SetTitle("#Delta#varphi_{h-h}")
st_h_h_dphi_50_80.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")

h_h_dphi_0_20.GetXaxis().SetTitle("#Delta#varphi_{h-h}")
h_h_dphi_0_20.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")
h_h_dphi_20_50.GetXaxis().SetTitle("#Delta#varphi_{h-h}")
h_h_dphi_20_50.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")
h_h_dphi_50_80.GetXaxis().SetTitle("#Delta#varphi_{h-h}")
h_h_dphi_50_80.GetYaxis().SetTitle("Per-trigger dN/d#Delta#varphi for constant #Delta#eta (rad^{-1})")

# %%
st_h_lambda_dphi_subtracted_0_20.SetLineColor(rt.kPink - 2)
st_h_lambda_dphi_subtracted_20_50.SetLineColor(rt.kOrange - 4)
st_h_lambda_dphi_subtracted_50_80.SetLineColor(rt.kBlue - 4)
h_lambda_dphi_subtracted_0_20.SetLineColor(rt.kPink - 2)
h_lambda_dphi_subtracted_20_50.SetLineColor(rt.kOrange - 4)
h_lambda_dphi_subtracted_50_80.SetLineColor(rt.kBlue - 4)
st_h_h_dphi_0_20.SetLineColor(rt.kPink - 6)
st_h_h_dphi_20_50.SetLineColor(rt.kOrange - 6)
st_h_h_dphi_50_80.SetLineColor(rt.kBlue - 6)
h_h_dphi_0_20.SetLineColor(rt.kPink - 6)
h_h_dphi_20_50.SetLineColor(rt.kOrange - 6)
h_h_dphi_50_80.SetLineColor(rt.kBlue - 6)

st_h_lambda_dphi_subtracted_0_20.SetLineWidth(2)
st_h_lambda_dphi_subtracted_20_50.SetLineWidth(2)
st_h_lambda_dphi_subtracted_50_80.SetLineWidth(2)
h_lambda_dphi_subtracted_0_20.SetLineWidth(2)
h_lambda_dphi_subtracted_20_50.SetLineWidth(2)
h_lambda_dphi_subtracted_50_80.SetLineWidth(2)
st_h_h_dphi_0_20.SetLineWidth(2)
st_h_h_dphi_20_50.SetLineWidth(2)
st_h_h_dphi_50_80.SetLineWidth(2)
h_h_dphi_0_20.SetLineWidth(2)
h_h_dphi_20_50.SetLineWidth(2)
h_h_dphi_50_80.SetLineWidth(2)

st_h_lambda_dphi_subtracted_0_20.SetMarkerStyle(21)
st_h_lambda_dphi_subtracted_20_50.SetMarkerStyle(21)
st_h_lambda_dphi_subtracted_50_80.SetMarkerStyle(21)
h_lambda_dphi_subtracted_0_20.SetMarkerStyle(25)
h_lambda_dphi_subtracted_20_50.SetMarkerStyle(25)
h_lambda_dphi_subtracted_50_80.SetMarkerStyle(25)

st_h_h_dphi_0_20.SetMarkerStyle(20)
st_h_h_dphi_20_50.SetMarkerStyle(20)
st_h_h_dphi_50_80.SetMarkerStyle(20)
h_h_dphi_0_20.SetMarkerStyle(24)
h_h_dphi_20_50.SetMarkerStyle(24)
h_h_dphi_50_80.SetMarkerStyle(24)

st_h_lambda_dphi_subtracted_0_20.SetMarkerColor(rt.kPink - 2)
st_h_lambda_dphi_subtracted_20_50.SetMarkerColor(rt.kOrange - 4)
st_h_lambda_dphi_subtracted_50_80.SetMarkerColor(rt.kBlue - 4)
h_lambda_dphi_subtracted_0_20.SetMarkerColor(rt.kPink - 2)
h_lambda_dphi_subtracted_20_50.SetMarkerColor(rt.kOrange - 4)
h_lambda_dphi_subtracted_50_80.SetMarkerColor(rt.kBlue - 4)

st_h_h_dphi_0_20.SetMarkerColor(rt.kPink - 6)
st_h_h_dphi_20_50.SetMarkerColor(rt.kOrange - 6)
st_h_h_dphi_50_80.SetMarkerColor(rt.kBlue - 6)
h_h_dphi_0_20.SetMarkerColor(rt.kPink - 6)
h_h_dphi_20_50.SetMarkerColor(rt.kOrange - 6)
h_h_dphi_50_80.SetMarkerColor(rt.kBlue - 6)

# %%
h_h_dphi_0_20.GetYaxis().SetRangeUser(st_h_h_dphi_0_20.GetMinimum() * 0.8, h_h_dphi_0_20.GetMaximum() * 1.2)
h_h_dphi_20_50.GetYaxis().SetRangeUser(st_h_h_dphi_20_50.GetMinimum() * 0.8, h_h_dphi_20_50.GetMaximum() * 1.2)
h_h_dphi_50_80.GetYaxis().SetRangeUser(st_h_h_dphi_50_80.GetMinimum() * 0.8, h_h_dphi_50_80.GetMaximum() * 1.2)

h_lambda_dphi_subtracted_0_20.GetYaxis().SetRangeUser(h_lambda_dphi_subtracted_0_20.GetMinimum() * 0.8, st_h_lambda_dphi_subtracted_0_20.GetMaximum() * 1.2)
h_lambda_dphi_subtracted_20_50.GetYaxis().SetRangeUser(h_lambda_dphi_subtracted_20_50.GetMinimum() * 0.8, st_h_lambda_dphi_subtracted_20_50.GetMaximum() * 1.2)
h_lambda_dphi_subtracted_50_80.GetYaxis().SetRangeUser(h_lambda_dphi_subtracted_50_80.GetMinimum() * 0.8, st_h_lambda_dphi_subtracted_50_80.GetMaximum() * 1.2)

# %%
h_h_dphi_0_20.Draw()
st_h_h_dphi_0_20.Draw("SAME")
leg = rt.TLegend(0.65, 0.7, 0.82, 0.82)
leg.AddEntry(st_h_h_dphi_0_20, "Single-trigger", "lp")
leg.AddEntry(h_h_dphi_0_20, "All-trigger", "lp")
leg.SetBorderSize(0)
leg.Draw("SAME")
label_x_start = 0.65
label_y_start = 0.92
label_text_space = 0.049

alice_data_label = rt.TLatex()
alice_data_label.SetNDC()
alice_data_label.SetTextSize(0.03)
alice_data_label.SetTextAlign(13)
alice_data_label.DrawLatex(label_x_start, label_y_start - label_text_space - 0.005, "0-20% V0A centrality")
c.Draw()
c.SaveAs("figures/h_h_dphi_0_20_singletrigger.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file figures/h_h_dphi_0_20_singletrigger.pdf has been created

# %%
h_h_dphi_20_50.Draw()
st_h_h_dphi_20_50.Draw("SAME")
leg = rt.TLegend(0.65, 0.7, 0.82, 0.82)
leg.AddEntry(st_h_h_dphi_20_50, "Single-trigger", "lp")
leg.AddEntry(h_h_dphi_20_50, "All-trigger", "lp")
leg.SetBorderSize(0)
leg.Draw("SAME")
label_x_start = 0.65
label_y_start = 0.92
label_text_space = 0.049
alice_data_label = rt.TLatex()
alice_data_label.SetNDC()
alice_data_label.SetTextSize(0.03)
alice_data_label.SetTextAlign(13)
alice_data_label.DrawLatex(label_x_start, label_y_start - label_text_space - 0.005, "20-50% V0A centrality")
c.Draw()
c.SaveAs("figures/h_h_dphi_20_50_singletrigger.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file figures/h_h_dphi_20_50_singletrigger.pdf has been created

# %%
h_h_dphi_50_80.Draw()
st_h_h_dphi_50_80.Draw("SAME")
leg = rt.TLegend(0.65, 0.7, 0.82, 0.82)
leg.AddEntry(st_h_h_dphi_50_80, "Single-trigger", "lp")
leg.AddEntry(h_h_dphi_50_80, "All-trigger", "lp")
leg.SetBorderSize(0)
leg.Draw("SAME")
label_x_start = 0.65
label_y_start = 0.92
label_text_space = 0.049
alice_data_label = rt.TLatex()
alice_data_label.SetNDC()
alice_data_label.SetTextSize(0.03)
alice_data_label.SetTextAlign(13)
alice_data_label.DrawLatex(label_x_start, label_y_start - label_text_space - 0.005, "50-80% V0A centrality")
c.Draw()
c.SaveAs("figures/h_h_dphi_50_80_singletrigger.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file figures/h_h_dphi_50_80_singletrigger.pdf has been created

# %%
h_lambda_dphi_subtracted_0_20.Draw()
st_h_lambda_dphi_subtracted_0_20.Draw("SAME")
leg = rt.TLegend(0.65, 0.7, 0.82, 0.82)
leg.AddEntry(st_h_lambda_dphi_subtracted_0_20, "Single-trigger", "lp")
leg.AddEntry(h_lambda_dphi_subtracted_0_20, "All-trigger", "lp")
leg.SetBorderSize(0)
leg.Draw("SAME")
label_x_start = 0.65
label_y_start = 0.92
label_text_space = 0.049
alice_data_label = rt.TLatex()
alice_data_label.SetNDC()
alice_data_label.SetTextSize(0.03)
alice_data_label.SetTextAlign(13)
alice_data_label.DrawLatex(label_x_start, label_y_start - label_text_space - 0.005, "0-20% V0A centrality")
c.Draw()
c.SaveAs("figures/h_lambda_dphi_subtracted_0_20_singletrigger.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file figures/h_lambda_dphi_subtracted_0_20_singletrigger.pdf has been created

# %%
h_lambda_dphi_subtracted_20_50.Draw()
st_h_lambda_dphi_subtracted_20_50.Draw("SAME")
leg = rt.TLegend(0.65, 0.7, 0.82, 0.82)
leg.AddEntry(st_h_lambda_dphi_subtracted_20_50, "Single-trigger", "lp")
leg.AddEntry(h_lambda_dphi_subtracted_20_50, "All-trigger", "lp")
leg.SetBorderSize(0)
leg.Draw("SAME")
label_x_start = 0.65
label_y_start = 0.92
label_text_space = 0.049
alice_data_label = rt.TLatex()
alice_data_label.SetNDC()
alice_data_label.SetTextSize(0.03)
alice_data_label.SetTextAlign(13)
alice_data_label.DrawLatex(label_x_start, label_y_start - label_text_space - 0.005, "20-50% V0A centrality")
c.Draw()
c.SaveAs("figures/h_lambda_dphi_subtracted_20_50_singletrigger.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file figures/h_lambda_dphi_subtracted_20_50_singletrigger.pdf has been created

# %%
h_lambda_dphi_subtracted_50_80.Draw()
st_h_lambda_dphi_subtracted_50_80.Draw("SAME")
leg = rt.TLegend(0.65, 0.7, 0.82, 0.82)
leg.AddEntry(st_h_lambda_dphi_subtracted_50_80, "Single-trigger", "lp")
leg.AddEntry(h_lambda_dphi_subtracted_50_80, "All-trigger", "lp")
leg.SetBorderSize(0)
leg.Draw("SAME")
label_x_start = 0.65
label_y_start = 0.92
label_text_space = 0.049
alice_data_label = rt.TLatex()
alice_data_label.SetNDC()
alice_data_label.SetTextSize(0.03)
alice_data_label.SetTextAlign(13)
alice_data_label.DrawLatex(label_x_start, label_y_start - label_text_space - 0.005, "50-80% V0A centrality")
c.Draw()
c.SaveAs("figures/h_lambda_dphi_subtracted_50_80_singletrigger.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file figures/h_lambda_dphi_subtracted_50_80_singletrigger.pdf has been created

# %%
h_h_ratio_0_20 = st_h_h_dphi_0_20.Clone("h_h_ratio_0_20")
h_h_ratio_0_20.Divide(h_h_dphi_0_20)

h_h_ratio_20_50 = st_h_h_dphi_20_50.Clone("h_h_ratio_20_50")
h_h_ratio_20_50.Divide(h_h_dphi_20_50)

h_h_ratio_50_80 = st_h_h_dphi_50_80.Clone("h_h_ratio_50_80")
h_h_ratio_50_80.Divide(h_h_dphi_50_80)

h_lambda_ratio_0_20 = st_h_lambda_dphi_subtracted_0_20.Clone("h_lambda_ratio_0_20")
h_lambda_ratio_0_20.Divide(h_lambda_dphi_subtracted_0_20)

h_lambda_ratio_20_50 = st_h_lambda_dphi_subtracted_20_50.Clone("h_lambda_ratio_20_50")
h_lambda_ratio_20_50.Divide(h_lambda_dphi_subtracted_20_50)

h_lambda_ratio_50_80 = st_h_lambda_dphi_subtracted_50_80.Clone("h_lambda_ratio_50_80")
h_lambda_ratio_50_80.Divide(h_lambda_dphi_subtracted_50_80)
# Out:
# True

# %%
h_h_ratio_0_20.GetXaxis().SetTitle("#Delta#varphi (rad)")
h_h_ratio_20_50.GetXaxis().SetTitle("#Delta#varphi (rad)")
h_h_ratio_50_80.GetXaxis().SetTitle("#Delta#varphi (rad)")

# %%
h_h_ratio_0_20.GetYaxis().SetRangeUser(0.2, 1.8)
h_h_ratio_0_20.Draw()
h_lambda_ratio_0_20.Draw("SAME")
leg = rt.TLegend(0.65, 0.7, 0.85, 0.82)
leg.AddEntry(h_h_ratio_0_20, "h-h ST/AT ratio", "lp")
leg.AddEntry(h_lambda_ratio_0_20, "h-#Lambda ST/AT ratio", "lp")
leg.SetBorderSize(0)
leg.Draw("SAME")
label_x_start = 0.65
label_y_start = 0.92
label_text_space = 0.049
alice_data_label = rt.TLatex()
alice_data_label.SetNDC()
alice_data_label.SetTextSize(0.03)
alice_data_label.SetTextAlign(13)
alice_data_label.DrawLatex(label_x_start, label_y_start - label_text_space - 0.005, "0-20% V0A centrality")
c.Draw()
c.SaveAs("figures/singletrigger_ratio_0_20.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file figures/singletrigger_ratio_0_20.pdf has been created

# %%
h_h_ratio_20_50.GetYaxis().SetRangeUser(0.2, 1.8)
h_h_ratio_20_50.Draw()
h_lambda_ratio_20_50.Draw("SAME")
leg = rt.TLegend(0.65, 0.7, 0.85, 0.82)
leg.AddEntry(h_h_ratio_20_50, "h-h ST/AT ratio", "lp")
leg.AddEntry(h_lambda_ratio_20_50, "h-#Lambda ST/AT ratio", "lp")
leg.SetBorderSize(0)
leg.Draw("SAME")
label_x_start = 0.65
label_y_start = 0.92
label_text_space = 0.049
alice_data_label = rt.TLatex()
alice_data_label.SetNDC()
alice_data_label.SetTextSize(0.03)
alice_data_label.SetTextAlign(13)
alice_data_label.DrawLatex(label_x_start, label_y_start - label_text_space - 0.005, "20-50% V0A centrality")
c.Draw()
c.SaveAs("figures/singletrigger_ratio_20_50.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file figures/singletrigger_ratio_20_50.pdf has been created

# %%
h_h_ratio_50_80.GetYaxis().SetRangeUser(0.2, 1.8)
h_h_ratio_50_80.Draw()
h_lambda_ratio_50_80.Draw("SAME")
leg = rt.TLegend(0.65, 0.7, 0.85, 0.82)
leg.AddEntry(h_h_ratio_50_80, "h-h ST/AT ratio", "lp")
leg.AddEntry(h_lambda_ratio_50_80, "h-#Lambda ST/AT ratio", "lp")
leg.SetBorderSize(0)
leg.Draw("SAME")
label_x_start = 0.65
label_y_start = 0.92
label_text_space = 0.049
alice_data_label = rt.TLatex()
alice_data_label.SetNDC()
alice_data_label.SetTextSize(0.03)
alice_data_label.SetTextAlign(13)
alice_data_label.DrawLatex(label_x_start, label_y_start - label_text_space - 0.005, "50-80% V0A centrality")
c.Draw()
c.SaveAs("figures/singletrigger_ratio_50_80.pdf")
# Out:
# Info in <TCanvas::Print>: pdf file figures/singletrigger_ratio_50_80.pdf has been created
