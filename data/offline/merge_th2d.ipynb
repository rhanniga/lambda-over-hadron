# %%
import ROOT as rt
# Out:
# Welcome to JupyROOT 6.24/06

# %%
c = rt.TCanvas("c","c",800,600)

# %%
infile = rt.TFile("../../mc/online/AnalysisResults.root")
in_list = infile.Get("h-lambda_eff")
inin_list = in_list.FindObject("eventTH2DList")

# %%
t = rt.TH2D("t","t", 20, 1, 2, 20, -0.8, 0.8)
for i in range(20):
    h = inin_list.At(i)
    t.Add(h)
t.Draw("colz")
c.Draw()
