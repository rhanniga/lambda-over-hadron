# %%
import ROOT as rt
# Out:
# Welcome to JupyROOT 6.28/02

# %%
infile = rt.TFile("phsd_out_60mil.root")
indist = infile.Get("lambda_dist")
c = rt.TCanvas("c","c",800,600)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
indist.GetAxis(2).SetRangeUser(-1, 1)
indist.Projection(0).Draw()
c.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: lambda_dist_proj_0 (Potential memory leak).

# %%
indist.Projection(1).Draw()
c.Draw()
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: lambda_dist_proj_1 (Potential memory leak).
